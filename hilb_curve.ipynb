# %%
def hilbert(x, y, xi, xj, yi, yj, n):
# x and y are the coordinates of the bottom left corner */
# xi & xj are the i & j components of the unit x vector of the frame */
# similarly yi and yj *

    if (n <= 0):
        Xlist.append(x + (xi + yi)/2)
        Ylist.append(y + (xj + yj)/2)
    else:
        hilbert(x, y, yi/2, yj/2, xi/2, xj/2, n-1)
        hilbert(x+xi/2, y+xj/2 , xi/2, xj/2, yi/2, yj/2, n-1)
        hilbert(x+xi/2+yi/2, y+xj/2+yj/2, xi/2, xj/2, yi/2, yj/2, n-1)
        hilbert(x+xi/2+yi, y+xj/2+yj, -yi/2,-yj/2, -xi/2, -xj/2, n-1)
    return Xlist, Ylist

# %%
Xlist = []
Ylist = []
hilbert(0, 0, 1, 0, 0, 1, 1)
plt.plot(Xlist, Ylist, 'b')

# %%
Xlist = []
Ylist = []
hilbert(0, 0, 1, 0, 0, 1, 2)
plt.plot(Xlist, Ylist, 'b')

# %%
Xlist = []
Ylist = []
hilbert(0, 0, 1, 0, 0, 1, 3)
plt.plot(Xlist, Ylist, 'b')

# %%
Xlist = []
Ylist = []
hilbert(0, 0, 1, 0, 0, 1, 4)
plt.plot(Xlist, Ylist, 'b')

# %%
Xlist = []
Ylist = []
hilbert(0, 0, 1, 0, 0, 1, 5)
plt.plot(Xlist, Ylist, 'b')

# %%
Xlist = []
Ylist = []
hilbert(0, 0, 1, 0, 0, 1, 6)
plt.plot(Xlist, Ylist, 'b')

# %%
Xlist = []
Ylist = []
hilbert(0, 0, 1, 0, 0, 1, 7)
plt.plot(Xlist, Ylist, 'b')

# %%
Xlist = []
Ylist = []
hilbert(0, 0, 1, 0, 0, 1, 8)
plt.plot(Xlist, Ylist, 'b')
